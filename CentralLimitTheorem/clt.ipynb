# %%
from scipy.stats import rv_discrete
import numpy as np

# %%
import centralLimitTheorem as clt
import scipy

# %%
def create_uniform_sample_distribution():
    return range(100)

def poisson_gen(self, x, mu):
        return np.exp(-mu) * mu**x / np.math.factorial(x)

def run():
    sampleDistribution = create_uniform_sample_distribution()
        
    # Plot the original population distribution
    clt.plot_distribution(sampleDistribution, "Population Distribution", 0, 100, 20)
        
    # Plot a sampling distribution for values of N = 2, 3, 10, and 30
    cltDemo = clt.CentralLimitTheoremDemo(sampleDistribution)
    n_vals = [2, 3, 10, 30]
    for N in n_vals:
        cltDemo.run_sample_demo(N = N, plot = True, num_bins = 40)

# %%
run()

# %%
x= create_uniform_sample_distribution()

# %%
scipy.stats.poisson.rvs(10)
# Out:
# 12

# %%
class poisson_gen(rv_discrete):
    def _pmf(self, x, mu):
        return np.exp(-mu) * mu**x / np.math.factorial(x)

# %%
nitesh = poisson_gen()

# %%
print('95/% Confidence Interval for N = %d is [%f , %f]' % (10, 9.99, 10.01))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-11d3eba825cb> in <module>()
# ----> 1 print('95/% Confidence Interval for N = %d is [%f , %f]' % (10, 9.99, 10.01))
#
# ValueError: unsupported format character 'C' (0x43) at index 5
